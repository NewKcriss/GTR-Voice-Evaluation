# %%
import itertools
import random
from pprint import pprint
from natsort import natsorted

random.seed(42)

# 定义G、T、R的范围
G_range = [1, 2, 3, 4]
T_range = [1, 2, 3, 4, 5]
R_range = [1, 2, 3, 4, 5, 6]

whisper_combinations = [(0,t,0) for t in T_range]

# 生成所有可能的GTR组合
all_combinations = list(itertools.product(G_range, T_range, R_range))
# 重新组织代码，以按G组、T组、R组分类trials，然后再进行sub-section分配

# 初始化用于存储按G、T、R组分类的trials的字典
trials_by_g = []
trials_by_t = []
trials_by_r = []

# 在一个trial中，包括reference在内，最多给参与者听4个音频
# 因此，对于每个参考样式，我们将选择最多2个变化探针

def select_variants(variants, limit=2):
    # 如果变化探针数量超过限制，则随机选择
    if len(variants) > limit:
        return random.sample(variants, limit)
    return variants

# 生成trials的函数，以选择限定数量的变化探针
def trials_for_dimension(dimension, limit=2):
    trials = []
    for g, t, r in all_combinations:
        reference = f'{g}{t}{r}'
        correct_probe = reference
        if dimension == 'G':
            variant_probes = select_variants([f'{g_var}{t}{r}' for g_var in G_range if g_var != g], limit)
        elif dimension == 'T':
            variant_probes = select_variants([f'{g}{t_var}{r}' for t_var in T_range if t_var != t], limit)
        else: # dimesion == 'R'
            variant_probes = select_variants([f'{g}{t}{r_var}' for r_var in R_range if r_var != r], limit)
        trials.append({
            'dimension': dimension,
            'reference': reference, 
            'correct_probe': correct_probe, 
            'variant_probes': variant_probes
        })
    return trials

def generate_whisper_combinations_trials(T_range, limit=2):
    whisper_trials = []
    for t in T_range:
        reference = f'0{t}0'
        correct_probe = reference
        # 对于T维度，variant_probes从其他T值中选择，但G和R保持为0
        variant_probes = select_variants([f'0{t_var}0' for t_var in T_range if t_var != t], limit)
        whisper_trials.append({
            'dimension': 'T',  # 特殊组合主要用于探查T维度
            'reference': reference,
            'correct_probe': correct_probe,
            'variant_probes': variant_probes
        })
    return whisper_trials

whisper_combinations_trials = generate_whisper_combinations_trials(T_range)

# 生成各维度的trials
trials_g = trials_for_dimension('G')
trials_t = trials_for_dimension('T')
trials_r = trials_for_dimension('R')
num_sub_sections = 1

# 合并所有trials并随机分配到sub-sections
all_trials_combined = trials_g + trials_t + trials_r 
all_trials_combined += whisper_combinations_trials

# 随机打乱trials顺序
random.shuffle(all_trials_combined) 

sub_sections_combined = [all_trials_combined[i::num_sub_sections] for i in range(num_sub_sections)]

# 打印每个sub-section的trials，标记评估的维度
for i, sub_section in enumerate(sub_sections_combined, start=1):
    print(f"Sub-section {i}:")
    for trial in sub_section:
        print(f"Dimension: {trial['dimension']}, Reference: {trial['reference']}, Correct Probe: {trial['correct_probe']}, Variant Probes: {trial['variant_probes']}")
    print("\n")

# natsorted(sub_sections_combined)


# len of each sub-section
print([len(sub_section) for sub_section in sub_sections_combined])


# len of all trials
print(len(all_trials_combined))
# Out:
# Sub-section 1:
# Dimension: T, Reference: 351, Correct Probe: 351, Variant Probes: ['321', '311']
# Dimension: T, Reference: 314, Correct Probe: 314, Variant Probes: ['324', '334']
# Dimension: R, Reference: 121, Correct Probe: 121, Variant Probes: ['123', '126']
# Dimension: R, Reference: 133, Correct Probe: 133, Variant Probes: ['132', '131']
# Dimension: R, Reference: 341, Correct Probe: 341, Variant Probes: ['342', '346']
# Dimension: G, Reference: 421, Correct Probe: 421, Variant Probes: ['121', '321']
# Dimension: T, Reference: 246, Correct Probe: 246, Variant Probes: ['216', '256']
# Dimension: R, Reference: 143, Correct Probe: 143, Variant Probes: ['142', '145']
# Dimension: R, Reference: 325, Correct Probe: 325, Variant Probes: ['326', '322']
# Dimension: R, Reference: 333, Correct Probe: 333, Variant Probes: ['335', '334']
# Dimension: G, Reference: 213, Correct Probe: 213, Variant Probes: ['413', '113']
# Dimension: T, Reference: 145, Correct Probe: 145, Variant Probes: ['115', '135']
# Dimension: T, Reference: 346, Correct Probe: 346, Variant Probes: ['336', '316']
# Dimension: G, Reference: 436, Correct Probe: 436, Variant Probes: ['236', '336']
# Dimension: R, Reference: 432, Correct Probe: 432, Variant Probes: ['433', '435']
# Dimension: G, Reference: 321, Correct Probe: 321, Variant Probes: ['221', '121']
# Dimension: G, Reference: 234, Correct Probe: 234, Variant Probes: ['134', '334']
# Dimension: R, Reference: 423, Correct Probe: 423, Variant Probes: ['421', '424']
# Dimension: R, Reference: 244, Correct Probe: 244, Variant Probes: ['245', '242']
# Dimension: T, Reference: 133, Correct Probe: 133, Variant Probes: ['143', '113']
# Dimension: T, Reference: 232, Correct Probe: 232, Variant Probes: ['242', '252']
# Dimension: G, Reference: 346, Correct Probe: 346, Variant Probes: ['446', '146']
# Dimension: G, Reference: 126, Correct Probe: 126, Variant Probes: ['226', '426']
# Dimension: G, Reference: 341, Correct Probe: 341, Variant Probes: ['141', '441']
# Dimension: R, Reference: 132, Correct Probe: 132, Variant Probes: ['135', '133']
# Dimension: T, Reference: 413, Correct Probe: 413, Variant Probes: ['433', '443']
# Dimension: R, Reference: 231, Correct Probe: 231, Variant Probes: ['236', '235']
# Dimension: T, Reference: 234, Correct Probe: 234, Variant Probes: ['244', '214']
# Dimension: R, Reference: 255, Correct Probe: 255, Variant Probes: ['253', '254']
# Dimension: R, Reference: 114, Correct Probe: 114, Variant Probes: ['113', '116']
# Dimension: T, Reference: 456, Correct Probe: 456, Variant Probes: ['436', '426']
# Dimension: G, Reference: 155, Correct Probe: 155, Variant Probes: ['255', '355']
# Dimension: R, Reference: 314, Correct Probe: 314, Variant Probes: ['313', '311']
# Dimension: R, Reference: 346, Correct Probe: 346, Variant Probes: ['345', '341']
# Dimension: R, Reference: 322, Correct Probe: 322, Variant Probes: ['321', '326']
# Dimension: G, Reference: 422, Correct Probe: 422, Variant Probes: ['122', '222']
# Dimension: G, Reference: 133, Correct Probe: 133, Variant Probes: ['233', '333']
# Dimension: R, Reference: 142, Correct Probe: 142, Variant Probes: ['141', '145']
# Dimension: G, Reference: 134, Correct Probe: 134, Variant Probes: ['334', '434']
# Dimension: G, Reference: 256, Correct Probe: 256, Variant Probes: ['456', '356']
# Dimension: G, Reference: 251, Correct Probe: 251, Variant Probes: ['451', '151']
# Dimension: G, Reference: 113, Correct Probe: 113, Variant Probes: ['213', '413']
# Dimension: G, Reference: 236, Correct Probe: 236, Variant Probes: ['436', '336']
# Dimension: R, Reference: 426, Correct Probe: 426, Variant Probes: ['423', '421']
# Dimension: T, Reference: 255, Correct Probe: 255, Variant Probes: ['245', '235']
# Dimension: R, Reference: 125, Correct Probe: 125, Variant Probes: ['124', '126']
# Dimension: G, Reference: 354, Correct Probe: 354, Variant Probes: ['254', '454']
# Dimension: R, Reference: 235, Correct Probe: 235, Variant Probes: ['236', '232']
# Dimension: T, Reference: 344, Correct Probe: 344, Variant Probes: ['324', '314']
# Dimension: R, Reference: 431, Correct Probe: 431, Variant Probes: ['435', '434']
# Dimension: G, Reference: 344, Correct Probe: 344, Variant Probes: ['144', '444']
# Dimension: T, Reference: 112, Correct Probe: 112, Variant Probes: ['122', '152']
# Dimension: G, Reference: 152, Correct Probe: 152, Variant Probes: ['252', '452']
# Dimension: R, Reference: 336, Correct Probe: 336, Variant Probes: ['332', '333']
# Dimension: T, Reference: 136, Correct Probe: 136, Variant Probes: ['126', '116']
# Dimension: G, Reference: 144, Correct Probe: 144, Variant Probes: ['444', '244']
# Dimension: R, Reference: 323, Correct Probe: 323, Variant Probes: ['321', '322']
# Dimension: R, Reference: 315, Correct Probe: 315, Variant Probes: ['314', '311']
# Dimension: G, Reference: 353, Correct Probe: 353, Variant Probes: ['453', '253']
# Dimension: G, Reference: 451, Correct Probe: 451, Variant Probes: ['351', '251']
# Dimension: T, Reference: 312, Correct Probe: 312, Variant Probes: ['322', '342']
# Dimension: R, Reference: 226, Correct Probe: 226, Variant Probes: ['224', '221']
# Dimension: G, Reference: 252, Correct Probe: 252, Variant Probes: ['452', '352']
# Dimension: R, Reference: 343, Correct Probe: 343, Variant Probes: ['345', '342']
# Dimension: G, Reference: 141, Correct Probe: 141, Variant Probes: ['341', '241']
# Dimension: R, Reference: 223, Correct Probe: 223, Variant Probes: ['226', '225']
# Dimension: T, Reference: 335, Correct Probe: 335, Variant Probes: ['345', '325']
# Dimension: G, Reference: 322, Correct Probe: 322, Variant Probes: ['422', '222']
# Dimension: T, Reference: 146, Correct Probe: 146, Variant Probes: ['126', '136']
# Dimension: G, Reference: 253, Correct Probe: 253, Variant Probes: ['453', '153']
# Dimension: G, Reference: 131, Correct Probe: 131, Variant Probes: ['331', '231']
# Dimension: G, Reference: 414, Correct Probe: 414, Variant Probes: ['314', '114']
# Dimension: R, Reference: 452, Correct Probe: 452, Variant Probes: ['453', '455']
# Dimension: R, Reference: 416, Correct Probe: 416, Variant Probes: ['414', '415']
# Dimension: G, Reference: 115, Correct Probe: 115, Variant Probes: ['415', '215']
# Dimension: G, Reference: 314, Correct Probe: 314, Variant Probes: ['414', '214']
# Dimension: R, Reference: 145, Correct Probe: 145, Variant Probes: ['144', '146']
# Dimension: T, Reference: 142, Correct Probe: 142, Variant Probes: ['112', '132']
# Dimension: G, Reference: 411, Correct Probe: 411, Variant Probes: ['111', '311']
# Dimension: R, Reference: 311, Correct Probe: 311, Variant Probes: ['315', '314']
# Dimension: T, Reference: 155, Correct Probe: 155, Variant Probes: ['135', '115']
# Dimension: T, Reference: 423, Correct Probe: 423, Variant Probes: ['433', '453']
# Dimension: T, Reference: 223, Correct Probe: 223, Variant Probes: ['233', '253']
# Dimension: R, Reference: 243, Correct Probe: 243, Variant Probes: ['245', '244']
# Dimension: T, Reference: 321, Correct Probe: 321, Variant Probes: ['341', '331']
# Dimension: T, Reference: 441, Correct Probe: 441, Variant Probes: ['451', '421']
# Dimension: T, Reference: 243, Correct Probe: 243, Variant Probes: ['233', '213']
# Dimension: T, Reference: 342, Correct Probe: 342, Variant Probes: ['312', '322']
# Dimension: T, Reference: 325, Correct Probe: 325, Variant Probes: ['315', '335']
# Dimension: T, Reference: 433, Correct Probe: 433, Variant Probes: ['443', '453']
# Dimension: T, Reference: 353, Correct Probe: 353, Variant Probes: ['333', '323']
# Dimension: T, Reference: 132, Correct Probe: 132, Variant Probes: ['112', '142']
# Dimension: G, Reference: 325, Correct Probe: 325, Variant Probes: ['425', '225']
# Dimension: G, Reference: 231, Correct Probe: 231, Variant Probes: ['431', '331']
# Dimension: R, Reference: 222, Correct Probe: 222, Variant Probes: ['225', '224']
# Dimension: T, Reference: 345, Correct Probe: 345, Variant Probes: ['355', '325']
# Dimension: R, Reference: 134, Correct Probe: 134, Variant Probes: ['131', '135']
# Dimension: R, Reference: 211, Correct Probe: 211, Variant Probes: ['214', '213']
# Dimension: G, Reference: 142, Correct Probe: 142, Variant Probes: ['442', '342']
# Dimension: R, Reference: 334, Correct Probe: 334, Variant Probes: ['333', '332']
# Dimension: T, Reference: 324, Correct Probe: 324, Variant Probes: ['334', '344']
# Dimension: R, Reference: 153, Correct Probe: 153, Variant Probes: ['152', '154']
# Dimension: G, Reference: 334, Correct Probe: 334, Variant Probes: ['234', '134']
# Dimension: R, Reference: 225, Correct Probe: 225, Variant Probes: ['222', '224']
# Dimension: T, Reference: 233, Correct Probe: 233, Variant Probes: ['213', '253']
# Dimension: R, Reference: 141, Correct Probe: 141, Variant Probes: ['142', '143']
# Dimension: T, Reference: 421, Correct Probe: 421, Variant Probes: ['441', '431']
# Dimension: T, Reference: 331, Correct Probe: 331, Variant Probes: ['321', '311']
# Dimension: G, Reference: 215, Correct Probe: 215, Variant Probes: ['115', '315']
# Dimension: T, Reference: 322, Correct Probe: 322, Variant Probes: ['312', '332']
# Dimension: G, Reference: 425, Correct Probe: 425, Variant Probes: ['125', '325']
# Dimension: R, Reference: 313, Correct Probe: 313, Variant Probes: ['314', '315']
# Dimension: G, Reference: 246, Correct Probe: 246, Variant Probes: ['146', '446']
# Dimension: G, Reference: 442, Correct Probe: 442, Variant Probes: ['342', '142']
# Dimension: R, Reference: 152, Correct Probe: 152, Variant Probes: ['155', '154']
# Dimension: R, Reference: 444, Correct Probe: 444, Variant Probes: ['446', '442']
# Dimension: G, Reference: 216, Correct Probe: 216, Variant Probes: ['316', '416']
# Dimension: G, Reference: 123, Correct Probe: 123, Variant Probes: ['223', '423']
# Dimension: T, Reference: 444, Correct Probe: 444, Variant Probes: ['424', '414']
# Dimension: G, Reference: 136, Correct Probe: 136, Variant Probes: ['436', '236']
# Dimension: T, Reference: 451, Correct Probe: 451, Variant Probes: ['421', '431']
# Dimension: G, Reference: 416, Correct Probe: 416, Variant Probes: ['316', '116']
# Dimension: G, Reference: 316, Correct Probe: 316, Variant Probes: ['216', '116']
# Dimension: R, Reference: 144, Correct Probe: 144, Variant Probes: ['146', '143']
# Dimension: G, Reference: 454, Correct Probe: 454, Variant Probes: ['254', '154']
# Dimension: G, Reference: 151, Correct Probe: 151, Variant Probes: ['351', '251']
# Dimension: G, Reference: 242, Correct Probe: 242, Variant Probes: ['442', '342']
# Dimension: R, Reference: 324, Correct Probe: 324, Variant Probes: ['322', '321']
# Dimension: T, Reference: 050, Correct Probe: 050, Variant Probes: ['010', '030']
# Dimension: G, Reference: 313, Correct Probe: 313, Variant Probes: ['413', '213']
# Dimension: T, Reference: 336, Correct Probe: 336, Variant Probes: ['326', '356']
# Dimension: T, Reference: 114, Correct Probe: 114, Variant Probes: ['154', '134']
# Dimension: R, Reference: 236, Correct Probe: 236, Variant Probes: ['234', '232']
# Dimension: R, Reference: 216, Correct Probe: 216, Variant Probes: ['212', '215']
# Dimension: T, Reference: 125, Correct Probe: 125, Variant Probes: ['155', '115']
# Dimension: G, Reference: 333, Correct Probe: 333, Variant Probes: ['433', '233']
# Dimension: T, Reference: 343, Correct Probe: 343, Variant Probes: ['313', '323']
# Dimension: G, Reference: 224, Correct Probe: 224, Variant Probes: ['124', '324']
# Dimension: R, Reference: 136, Correct Probe: 136, Variant Probes: ['135', '134']
# Dimension: R, Reference: 424, Correct Probe: 424, Variant Probes: ['425', '422']
# Dimension: T, Reference: 252, Correct Probe: 252, Variant Probes: ['212', '242']
# Dimension: G, Reference: 254, Correct Probe: 254, Variant Probes: ['354', '454']
# Dimension: T, Reference: 341, Correct Probe: 341, Variant Probes: ['321', '331']
# Dimension: R, Reference: 131, Correct Probe: 131, Variant Probes: ['135', '136']
# Dimension: T, Reference: 153, Correct Probe: 153, Variant Probes: ['133', '123']
# Dimension: G, Reference: 114, Correct Probe: 114, Variant Probes: ['414', '214']
# Dimension: R, Reference: 441, Correct Probe: 441, Variant Probes: ['446', '443']
# Dimension: G, Reference: 342, Correct Probe: 342, Variant Probes: ['442', '142']
# Dimension: G, Reference: 225, Correct Probe: 225, Variant Probes: ['325', '425']
# Dimension: R, Reference: 451, Correct Probe: 451, Variant Probes: ['452', '454']
# Dimension: R, Reference: 421, Correct Probe: 421, Variant Probes: ['426', '424']
# Dimension: R, Reference: 442, Correct Probe: 442, Variant Probes: ['441', '443']
# Dimension: T, Reference: 115, Correct Probe: 115, Variant Probes: ['155', '125']
# Dimension: T, Reference: 453, Correct Probe: 453, Variant Probes: ['413', '423']
# Dimension: T, Reference: 316, Correct Probe: 316, Variant Probes: ['336', '326']
# Dimension: R, Reference: 331, Correct Probe: 331, Variant Probes: ['335', '332']
# Dimension: T, Reference: 313, Correct Probe: 313, Variant Probes: ['333', '343']
# Dimension: T, Reference: 431, Correct Probe: 431, Variant Probes: ['451', '411']
# Dimension: R, Reference: 352, Correct Probe: 352, Variant Probes: ['354', '355']
# Dimension: T, Reference: 236, Correct Probe: 236, Variant Probes: ['226', '256']
# Dimension: R, Reference: 326, Correct Probe: 326, Variant Probes: ['322', '325']
# Dimension: T, Reference: 225, Correct Probe: 225, Variant Probes: ['255', '245']
# Dimension: R, Reference: 436, Correct Probe: 436, Variant Probes: ['435', '431']
# Dimension: T, Reference: 224, Correct Probe: 224, Variant Probes: ['244', '214']
# Dimension: G, Reference: 413, Correct Probe: 413, Variant Probes: ['313', '113']
# Dimension: T, Reference: 354, Correct Probe: 354, Variant Probes: ['314', '324']
# Dimension: G, Reference: 241, Correct Probe: 241, Variant Probes: ['441', '341']
# Dimension: G, Reference: 132, Correct Probe: 132, Variant Probes: ['232', '332']
# Dimension: R, Reference: 221, Correct Probe: 221, Variant Probes: ['222', '225']
# Dimension: R, Reference: 213, Correct Probe: 213, Variant Probes: ['214', '211']
# Dimension: T, Reference: 455, Correct Probe: 455, Variant Probes: ['445', '435']
# Dimension: T, Reference: 241, Correct Probe: 241, Variant Probes: ['231', '251']
# Dimension: G, Reference: 111, Correct Probe: 111, Variant Probes: ['311', '211']
# Dimension: T, Reference: 126, Correct Probe: 126, Variant Probes: ['136', '156']
# Dimension: R, Reference: 113, Correct Probe: 113, Variant Probes: ['112', '111']
# Dimension: G, Reference: 156, Correct Probe: 156, Variant Probes: ['356', '256']
# Dimension: T, Reference: 416, Correct Probe: 416, Variant Probes: ['456', '436']
# Dimension: R, Reference: 156, Correct Probe: 156, Variant Probes: ['154', '151']
# Dimension: R, Reference: 224, Correct Probe: 224, Variant Probes: ['225', '221']
# Dimension: G, Reference: 145, Correct Probe: 145, Variant Probes: ['445', '245']
# Dimension: R, Reference: 425, Correct Probe: 425, Variant Probes: ['424', '426']
# Dimension: G, Reference: 124, Correct Probe: 124, Variant Probes: ['424', '324']
# Dimension: R, Reference: 414, Correct Probe: 414, Variant Probes: ['416', '413']
# Dimension: G, Reference: 431, Correct Probe: 431, Variant Probes: ['131', '231']
# Dimension: T, Reference: 242, Correct Probe: 242, Variant Probes: ['222', '232']
# Dimension: R, Reference: 124, Correct Probe: 124, Variant Probes: ['126', '121']
# Dimension: T, Reference: 454, Correct Probe: 454, Variant Probes: ['434', '414']
# Dimension: T, Reference: 254, Correct Probe: 254, Variant Probes: ['234', '214']
# Dimension: G, Reference: 434, Correct Probe: 434, Variant Probes: ['334', '234']
# Dimension: R, Reference: 135, Correct Probe: 135, Variant Probes: ['132', '136']
# Dimension: R, Reference: 233, Correct Probe: 233, Variant Probes: ['234', '236']
# Dimension: R, Reference: 335, Correct Probe: 335, Variant Probes: ['336', '331']
# Dimension: T, Reference: 244, Correct Probe: 244, Variant Probes: ['234', '254']
# Dimension: T, Reference: 442, Correct Probe: 442, Variant Probes: ['452', '432']
# Dimension: G, Reference: 352, Correct Probe: 352, Variant Probes: ['152', '452']
# Dimension: G, Reference: 433, Correct Probe: 433, Variant Probes: ['133', '333']
# Dimension: G, Reference: 356, Correct Probe: 356, Variant Probes: ['156', '456']
# Dimension: T, Reference: 355, Correct Probe: 355, Variant Probes: ['335', '345']
# Dimension: R, Reference: 342, Correct Probe: 342, Variant Probes: ['344', '345']
# Dimension: T, Reference: 116, Correct Probe: 116, Variant Probes: ['156', '126']
# Dimension: T, Reference: 231, Correct Probe: 231, Variant Probes: ['211', '241']
# Dimension: G, Reference: 444, Correct Probe: 444, Variant Probes: ['344', '244']
# Dimension: R, Reference: 446, Correct Probe: 446, Variant Probes: ['444', '441']
# Dimension: G, Reference: 235, Correct Probe: 235, Variant Probes: ['135', '435']
# Dimension: G, Reference: 326, Correct Probe: 326, Variant Probes: ['426', '126']
# Dimension: G, Reference: 446, Correct Probe: 446, Variant Probes: ['146', '346']
# Dimension: T, Reference: 235, Correct Probe: 235, Variant Probes: ['215', '245']
# Dimension: T, Reference: 131, Correct Probe: 131, Variant Probes: ['121', '111']
# Dimension: T, Reference: 111, Correct Probe: 111, Variant Probes: ['121', '141']
# Dimension: G, Reference: 233, Correct Probe: 233, Variant Probes: ['333', '433']
# Dimension: T, Reference: 332, Correct Probe: 332, Variant Probes: ['322', '312']
# Dimension: R, Reference: 151, Correct Probe: 151, Variant Probes: ['153', '155']
# Dimension: T, Reference: 446, Correct Probe: 446, Variant Probes: ['456', '436']
# Dimension: T, Reference: 426, Correct Probe: 426, Variant Probes: ['436', '456']
# Dimension: G, Reference: 323, Correct Probe: 323, Variant Probes: ['423', '123']
# Dimension: T, Reference: 411, Correct Probe: 411, Variant Probes: ['441', '421']
# Dimension: T, Reference: 432, Correct Probe: 432, Variant Probes: ['442', '452']
# Dimension: T, Reference: 334, Correct Probe: 334, Variant Probes: ['324', '344']
# Dimension: G, Reference: 116, Correct Probe: 116, Variant Probes: ['416', '316']
# Dimension: T, Reference: 211, Correct Probe: 211, Variant Probes: ['231', '241']
# Dimension: R, Reference: 212, Correct Probe: 212, Variant Probes: ['214', '216']
# Dimension: T, Reference: 425, Correct Probe: 425, Variant Probes: ['455', '415']
# Dimension: T, Reference: 415, Correct Probe: 415, Variant Probes: ['425', '445']
# Dimension: T, Reference: 245, Correct Probe: 245, Variant Probes: ['255', '225']
# Dimension: R, Reference: 146, Correct Probe: 146, Variant Probes: ['145', '144']
# Dimension: R, Reference: 413, Correct Probe: 413, Variant Probes: ['415', '412']
# Dimension: R, Reference: 351, Correct Probe: 351, Variant Probes: ['356', '352']
# Dimension: R, Reference: 355, Correct Probe: 355, Variant Probes: ['351', '354']
# Dimension: R, Reference: 422, Correct Probe: 422, Variant Probes: ['424', '423']
# Dimension: G, Reference: 345, Correct Probe: 345, Variant Probes: ['145', '245']
# Dimension: T, Reference: 323, Correct Probe: 323, Variant Probes: ['333', '343']
# Dimension: R, Reference: 443, Correct Probe: 443, Variant Probes: ['445', '446']
# Dimension: T, Reference: 436, Correct Probe: 436, Variant Probes: ['446', '456']
# Dimension: G, Reference: 125, Correct Probe: 125, Variant Probes: ['325', '425']
# Dimension: T, Reference: 214, Correct Probe: 214, Variant Probes: ['224', '234']
# Dimension: G, Reference: 143, Correct Probe: 143, Variant Probes: ['443', '343']
# Dimension: R, Reference: 123, Correct Probe: 123, Variant Probes: ['122', '125']
# Dimension: T, Reference: 121, Correct Probe: 121, Variant Probes: ['131', '151']
# Dimension: T, Reference: 020, Correct Probe: 020, Variant Probes: ['040', '010']
# Dimension: T, Reference: 040, Correct Probe: 040, Variant Probes: ['010', '030']
# Dimension: G, Reference: 324, Correct Probe: 324, Variant Probes: ['424', '124']
# Dimension: R, Reference: 112, Correct Probe: 112, Variant Probes: ['113', '115']
# Dimension: G, Reference: 432, Correct Probe: 432, Variant Probes: ['232', '132']
# Dimension: T, Reference: 256, Correct Probe: 256, Variant Probes: ['246', '236']
# Dimension: R, Reference: 321, Correct Probe: 321, Variant Probes: ['324', '323']
# Dimension: T, Reference: 253, Correct Probe: 253, Variant Probes: ['233', '213']
# Dimension: R, Reference: 253, Correct Probe: 253, Variant Probes: ['252', '255']
# Dimension: G, Reference: 212, Correct Probe: 212, Variant Probes: ['412', '112']
# Dimension: G, Reference: 445, Correct Probe: 445, Variant Probes: ['145', '345']
# Dimension: G, Reference: 332, Correct Probe: 332, Variant Probes: ['132', '432']
# Dimension: T, Reference: 452, Correct Probe: 452, Variant Probes: ['432', '422']
# Dimension: R, Reference: 345, Correct Probe: 345, Variant Probes: ['341', '343']
# Dimension: T, Reference: 412, Correct Probe: 412, Variant Probes: ['422', '432']
# Dimension: T, Reference: 326, Correct Probe: 326, Variant Probes: ['356', '346']
# Dimension: R, Reference: 245, Correct Probe: 245, Variant Probes: ['244', '242']
# Dimension: T, Reference: 222, Correct Probe: 222, Variant Probes: ['242', '212']
# Dimension: G, Reference: 351, Correct Probe: 351, Variant Probes: ['251', '451']
# Dimension: R, Reference: 242, Correct Probe: 242, Variant Probes: ['245', '241']
# Dimension: R, Reference: 435, Correct Probe: 435, Variant Probes: ['433', '436']
# Dimension: G, Reference: 331, Correct Probe: 331, Variant Probes: ['131', '231']
# Dimension: T, Reference: 135, Correct Probe: 135, Variant Probes: ['155', '145']
# Dimension: R, Reference: 434, Correct Probe: 434, Variant Probes: ['433', '436']
# Dimension: R, Reference: 254, Correct Probe: 254, Variant Probes: ['252', '251']
# Dimension: R, Reference: 332, Correct Probe: 332, Variant Probes: ['336', '333']
# Dimension: T, Reference: 422, Correct Probe: 422, Variant Probes: ['412', '432']
# Dimension: G, Reference: 426, Correct Probe: 426, Variant Probes: ['326', '226']
# Dimension: R, Reference: 256, Correct Probe: 256, Variant Probes: ['253', '252']
# Dimension: G, Reference: 456, Correct Probe: 456, Variant Probes: ['356', '156']
# Dimension: G, Reference: 221, Correct Probe: 221, Variant Probes: ['421', '121']
# Dimension: T, Reference: 030, Correct Probe: 030, Variant Probes: ['020', '010']
# Dimension: R, Reference: 433, Correct Probe: 433, Variant Probes: ['432', '434']
# Dimension: T, Reference: 154, Correct Probe: 154, Variant Probes: ['124', '134']
# Dimension: R, Reference: 455, Correct Probe: 455, Variant Probes: ['454', '453']
# Dimension: G, Reference: 135, Correct Probe: 135, Variant Probes: ['235', '335']
# Dimension: R, Reference: 356, Correct Probe: 356, Variant Probes: ['354', '351']
# Dimension: R, Reference: 344, Correct Probe: 344, Variant Probes: ['341', '342']
# Dimension: R, Reference: 251, Correct Probe: 251, Variant Probes: ['255', '252']
# Dimension: T, Reference: 356, Correct Probe: 356, Variant Probes: ['346', '336']
# Dimension: G, Reference: 112, Correct Probe: 112, Variant Probes: ['212', '412']
# Dimension: R, Reference: 411, Correct Probe: 411, Variant Probes: ['415', '414']
# Dimension: G, Reference: 223, Correct Probe: 223, Variant Probes: ['123', '423']
# Dimension: G, Reference: 355, Correct Probe: 355, Variant Probes: ['255', '455']
# Dimension: T, Reference: 113, Correct Probe: 113, Variant Probes: ['133', '123']
# Dimension: G, Reference: 343, Correct Probe: 343, Variant Probes: ['143', '243']
# Dimension: G, Reference: 226, Correct Probe: 226, Variant Probes: ['126', '426']
# Dimension: T, Reference: 134, Correct Probe: 134, Variant Probes: ['114', '144']
# Dimension: G, Reference: 441, Correct Probe: 441, Variant Probes: ['341', '141']
# Dimension: G, Reference: 435, Correct Probe: 435, Variant Probes: ['235', '335']
# Dimension: G, Reference: 243, Correct Probe: 243, Variant Probes: ['343', '143']
# Dimension: G, Reference: 211, Correct Probe: 211, Variant Probes: ['411', '311']
# Dimension: T, Reference: 010, Correct Probe: 010, Variant Probes: ['020', '050']
# Dimension: T, Reference: 424, Correct Probe: 424, Variant Probes: ['414', '444']
# Dimension: T, Reference: 213, Correct Probe: 213, Variant Probes: ['243', '223']
# Dimension: T, Reference: 435, Correct Probe: 435, Variant Probes: ['445', '455']
# Dimension: T, Reference: 443, Correct Probe: 443, Variant Probes: ['433', '453']
# Dimension: T, Reference: 333, Correct Probe: 333, Variant Probes: ['353', '313']
# Dimension: R, Reference: 154, Correct Probe: 154, Variant Probes: ['156', '155']
# Dimension: G, Reference: 452, Correct Probe: 452, Variant Probes: ['152', '252']
# Dimension: T, Reference: 414, Correct Probe: 414, Variant Probes: ['444', '424']
# Dimension: R, Reference: 234, Correct Probe: 234, Variant Probes: ['235', '236']
# Dimension: G, Reference: 311, Correct Probe: 311, Variant Probes: ['411', '111']
# Dimension: T, Reference: 122, Correct Probe: 122, Variant Probes: ['112', '132']
# Dimension: G, Reference: 232, Correct Probe: 232, Variant Probes: ['132', '332']
# Dimension: T, Reference: 216, Correct Probe: 216, Variant Probes: ['236', '246']
# Dimension: R, Reference: 241, Correct Probe: 241, Variant Probes: ['244', '245']
# Dimension: G, Reference: 335, Correct Probe: 335, Variant Probes: ['135', '235']
# Dimension: G, Reference: 336, Correct Probe: 336, Variant Probes: ['236', '136']
# Dimension: R, Reference: 412, Correct Probe: 412, Variant Probes: ['415', '413']
# Dimension: R, Reference: 252, Correct Probe: 252, Variant Probes: ['251', '255']
# Dimension: G, Reference: 222, Correct Probe: 222, Variant Probes: ['422', '322']
# Dimension: R, Reference: 354, Correct Probe: 354, Variant Probes: ['356', '353']
# Dimension: T, Reference: 352, Correct Probe: 352, Variant Probes: ['322', '342']
# Dimension: G, Reference: 214, Correct Probe: 214, Variant Probes: ['414', '114']
# Dimension: G, Reference: 255, Correct Probe: 255, Variant Probes: ['455', '355']
# Dimension: R, Reference: 115, Correct Probe: 115, Variant Probes: ['111', '112']
# Dimension: T, Reference: 124, Correct Probe: 124, Variant Probes: ['144', '134']
# Dimension: G, Reference: 153, Correct Probe: 153, Variant Probes: ['353', '453']
# Dimension: R, Reference: 445, Correct Probe: 445, Variant Probes: ['444', '446']
# Dimension: T, Reference: 251, Correct Probe: 251, Variant Probes: ['241', '221']
# Dimension: T, Reference: 434, Correct Probe: 434, Variant Probes: ['414', '444']
# Dimension: R, Reference: 116, Correct Probe: 116, Variant Probes: ['113', '112']
# Dimension: R, Reference: 111, Correct Probe: 111, Variant Probes: ['115', '116']
# Dimension: T, Reference: 152, Correct Probe: 152, Variant Probes: ['112', '122']
# Dimension: R, Reference: 246, Correct Probe: 246, Variant Probes: ['245', '241']
# Dimension: G, Reference: 121, Correct Probe: 121, Variant Probes: ['221', '321']
# Dimension: G, Reference: 245, Correct Probe: 245, Variant Probes: ['145', '445']
# Dimension: R, Reference: 126, Correct Probe: 126, Variant Probes: ['125', '122']
# Dimension: R, Reference: 353, Correct Probe: 353, Variant Probes: ['354', '351']
# Dimension: R, Reference: 415, Correct Probe: 415, Variant Probes: ['416', '414']
# Dimension: T, Reference: 156, Correct Probe: 156, Variant Probes: ['136', '126']
# Dimension: R, Reference: 232, Correct Probe: 232, Variant Probes: ['235', '231']
# Dimension: G, Reference: 154, Correct Probe: 154, Variant Probes: ['354', '454']
# Dimension: G, Reference: 146, Correct Probe: 146, Variant Probes: ['246', '446']
# Dimension: T, Reference: 143, Correct Probe: 143, Variant Probes: ['113', '133']
# Dimension: G, Reference: 315, Correct Probe: 315, Variant Probes: ['115', '215']
# Dimension: R, Reference: 214, Correct Probe: 214, Variant Probes: ['212', '216']
# Dimension: G, Reference: 122, Correct Probe: 122, Variant Probes: ['422', '322']
# Dimension: T, Reference: 215, Correct Probe: 215, Variant Probes: ['225', '255']
# Dimension: G, Reference: 412, Correct Probe: 412, Variant Probes: ['212', '112']
# Dimension: T, Reference: 315, Correct Probe: 315, Variant Probes: ['335', '355']
# Dimension: G, Reference: 453, Correct Probe: 453, Variant Probes: ['153', '253']
# Dimension: T, Reference: 212, Correct Probe: 212, Variant Probes: ['242', '232']
# Dimension: G, Reference: 424, Correct Probe: 424, Variant Probes: ['224', '324']
# Dimension: G, Reference: 244, Correct Probe: 244, Variant Probes: ['144', '344']
# Dimension: T, Reference: 151, Correct Probe: 151, Variant Probes: ['111', '131']
# Dimension: R, Reference: 316, Correct Probe: 316, Variant Probes: ['315', '311']
# Dimension: R, Reference: 155, Correct Probe: 155, Variant Probes: ['152', '153']
# Dimension: R, Reference: 312, Correct Probe: 312, Variant Probes: ['314', '315']
# Dimension: T, Reference: 144, Correct Probe: 144, Variant Probes: ['124', '154']
# Dimension: R, Reference: 122, Correct Probe: 122, Variant Probes: ['121', '126']
# Dimension: G, Reference: 443, Correct Probe: 443, Variant Probes: ['143', '243']
# Dimension: R, Reference: 453, Correct Probe: 453, Variant Probes: ['452', '454']
# Dimension: G, Reference: 415, Correct Probe: 415, Variant Probes: ['115', '315']
# Dimension: R, Reference: 215, Correct Probe: 215, Variant Probes: ['212', '214']
# Dimension: R, Reference: 454, Correct Probe: 454, Variant Probes: ['456', '453']
# Dimension: T, Reference: 226, Correct Probe: 226, Variant Probes: ['246', '256']
# Dimension: G, Reference: 423, Correct Probe: 423, Variant Probes: ['123', '323']
# Dimension: G, Reference: 312, Correct Probe: 312, Variant Probes: ['412', '112']
# Dimension: G, Reference: 455, Correct Probe: 455, Variant Probes: ['155', '255']
# Dimension: T, Reference: 123, Correct Probe: 123, Variant Probes: ['143', '133']
# Dimension: T, Reference: 221, Correct Probe: 221, Variant Probes: ['241', '211']
# Dimension: T, Reference: 141, Correct Probe: 141, Variant Probes: ['111', '151']
# Dimension: T, Reference: 445, Correct Probe: 445, Variant Probes: ['455', '435']
# Dimension: R, Reference: 456, Correct Probe: 456, Variant Probes: ['454', '453']
# Dimension: T, Reference: 311, Correct Probe: 311, Variant Probes: ['321', '351']
#
#
# [365]
# 365

# %%
all_trials_combined[0]
# Out:
# {'dimension': 'T',
#  'reference': '351',
#  'correct_probe': '351',
#  'variant_probes': ['321', '311']}

# %%
import os

# initialize trials mapping
trials_mapping = {}

# base path
base_path = "/storageNVME/kcriss/gtr_dataset_evaluation/"

# iterate through all trials and create the directory structure
for i, trial in enumerate(all_trials_combined, start=1):
    dimension = trial['dimension']
    reference = trial['reference']
    correct_probe = trial['correct_probe']
    variant_probes = trial['variant_probes']

    # create paths
    dimension_path = os.path.join(base_path, dimension)
    reference_path = os.path.join(dimension_path, 'reference', reference)
    correct_probe_path = os.path.join(dimension_path, 'correct_probe', correct_probe)
    variant_probe_paths = [os.path.join(dimension_path, f'variant_probe_{idx+1}', vp) for idx, vp in enumerate(variant_probes)]

    # # create directories
    # os.makedirs(reference_path, exist_ok=True)
    # os.makedirs(correct_probe_path, exist_ok=True)
    # for vp_path in variant_probe_paths:
    #     os.makedirs(vp_path, exist_ok=True)
        
    # 更新映射表的键，使用维度和参考的组合
    key = f"Trail_{i}_{dimension}_{reference}"

    # 映射trial信息
    trials_mapping[key] = {
        'dimension': dimension,
        'reference_path': reference_path,
        'correct_probe_path': correct_probe_path,
        'variant_probe_paths': variant_probe_paths
    }

# 示范如何访问映射表中的信息
for key, info in trials_mapping.items():
    dimension, reference = key.split('_', 1)  # 分割键以获取维度和参考
    print(f"Key: {key}")
    print(f"Dimension: {dimension}, Reference: {reference}")
    print(f"Reference Path: {info['reference_path']}")
    print(f"Correct Probe Path: {info['correct_probe_path']}")
    for idx, vp_path in enumerate(info['variant_probe_paths'], start=1):
        print(f"Variant Probe {idx} Path: {vp_path}")
    print("\n")
# Out:
# Key: Trail_1_T_351
# Dimension: Trail, Reference: 1_T_351
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/reference/351
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/correct_probe/351
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_1/321
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_2/311
#
#
# Key: Trail_2_T_314
# Dimension: Trail, Reference: 2_T_314
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/reference/314
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/correct_probe/314
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_1/324
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_2/334
#
#
# Key: Trail_3_R_121
# Dimension: Trail, Reference: 3_R_121
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/reference/121
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/correct_probe/121
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_1/123
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_2/126
#
#
# Key: Trail_4_R_133
# Dimension: Trail, Reference: 4_R_133
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/reference/133
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/correct_probe/133
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_1/132
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_2/131
#
#
# Key: Trail_5_R_341
# Dimension: Trail, Reference: 5_R_341
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/reference/341
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/correct_probe/341
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_1/342
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_2/346
#
#
# Key: Trail_6_G_421
# Dimension: Trail, Reference: 6_G_421
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/reference/421
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/correct_probe/421
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_1/121
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_2/321
#
#
# Key: Trail_7_T_246
# Dimension: Trail, Reference: 7_T_246
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/reference/246
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/correct_probe/246
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_1/216
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_2/256
#
#
# Key: Trail_8_R_143
# Dimension: Trail, Reference: 8_R_143
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/reference/143
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/correct_probe/143
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_1/142
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_2/145
#
#
# Key: Trail_9_R_325
# Dimension: Trail, Reference: 9_R_325
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/reference/325
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/correct_probe/325
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_1/326
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_2/322
#
#
# Key: Trail_10_R_333
# Dimension: Trail, Reference: 10_R_333
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/reference/333
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/correct_probe/333
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_1/335
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_2/334
#
#
# Key: Trail_11_G_213
# Dimension: Trail, Reference: 11_G_213
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/reference/213
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/correct_probe/213
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_1/413
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_2/113
#
#
# Key: Trail_12_T_145
# Dimension: Trail, Reference: 12_T_145
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/reference/145
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/correct_probe/145
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_1/115
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_2/135
#
#
# Key: Trail_13_T_346
# Dimension: Trail, Reference: 13_T_346
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/reference/346
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/correct_probe/346
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_1/336
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_2/316
#
#
# Key: Trail_14_G_436
# Dimension: Trail, Reference: 14_G_436
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/reference/436
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/correct_probe/436
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_1/236
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_2/336
#
#
# Key: Trail_15_R_432
# Dimension: Trail, Reference: 15_R_432
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/reference/432
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/correct_probe/432
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_1/433
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_2/435
#
#
# Key: Trail_16_G_321
# Dimension: Trail, Reference: 16_G_321
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/reference/321
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/correct_probe/321
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_1/221
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_2/121
#
#
# Key: Trail_17_G_234
# Dimension: Trail, Reference: 17_G_234
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/reference/234
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/correct_probe/234
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_1/134
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_2/334
#
#
# Key: Trail_18_R_423
# Dimension: Trail, Reference: 18_R_423
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/reference/423
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/correct_probe/423
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_1/421
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_2/424
#
#
# Key: Trail_19_R_244
# Dimension: Trail, Reference: 19_R_244
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/reference/244
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/correct_probe/244
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_1/245
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_2/242
#
#
# Key: Trail_20_T_133
# Dimension: Trail, Reference: 20_T_133
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/reference/133
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/correct_probe/133
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_1/143
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_2/113
#
#
# Key: Trail_21_T_232
# Dimension: Trail, Reference: 21_T_232
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/reference/232
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/correct_probe/232
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_1/242
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_2/252
#
#
# Key: Trail_22_G_346
# Dimension: Trail, Reference: 22_G_346
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/reference/346
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/correct_probe/346
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_1/446
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_2/146
#
#
# Key: Trail_23_G_126
# Dimension: Trail, Reference: 23_G_126
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/reference/126
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/correct_probe/126
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_1/226
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_2/426
#
#
# Key: Trail_24_G_341
# Dimension: Trail, Reference: 24_G_341
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/reference/341
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/correct_probe/341
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_1/141
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_2/441
#
#
# Key: Trail_25_R_132
# Dimension: Trail, Reference: 25_R_132
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/reference/132
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/correct_probe/132
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_1/135
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_2/133
#
#
# Key: Trail_26_T_413
# Dimension: Trail, Reference: 26_T_413
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/reference/413
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/correct_probe/413
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_1/433
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_2/443
#
#
# Key: Trail_27_R_231
# Dimension: Trail, Reference: 27_R_231
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/reference/231
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/correct_probe/231
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_1/236
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_2/235
#
#
# Key: Trail_28_T_234
# Dimension: Trail, Reference: 28_T_234
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/reference/234
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/correct_probe/234
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_1/244
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_2/214
#
#
# Key: Trail_29_R_255
# Dimension: Trail, Reference: 29_R_255
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/reference/255
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/correct_probe/255
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_1/253
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_2/254
#
#
# Key: Trail_30_R_114
# Dimension: Trail, Reference: 30_R_114
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/reference/114
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/correct_probe/114
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_1/113
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_2/116
#
#
# Key: Trail_31_T_456
# Dimension: Trail, Reference: 31_T_456
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/reference/456
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/correct_probe/456
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_1/436
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_2/426
#
#
# Key: Trail_32_G_155
# Dimension: Trail, Reference: 32_G_155
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/reference/155
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/correct_probe/155
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_1/255
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_2/355
#
#
# Key: Trail_33_R_314
# Dimension: Trail, Reference: 33_R_314
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/reference/314
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/correct_probe/314
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_1/313
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_2/311
#
#
# Key: Trail_34_R_346
# Dimension: Trail, Reference: 34_R_346
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/reference/346
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/correct_probe/346
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_1/345
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_2/341
#
#
# Key: Trail_35_R_322
# Dimension: Trail, Reference: 35_R_322
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/reference/322
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/correct_probe/322
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_1/321
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_2/326
#
#
# Key: Trail_36_G_422
# Dimension: Trail, Reference: 36_G_422
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/reference/422
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/correct_probe/422
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_1/122
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_2/222
#
#
# Key: Trail_37_G_133
# Dimension: Trail, Reference: 37_G_133
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/reference/133
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/correct_probe/133
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_1/233
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_2/333
#
#
# Key: Trail_38_R_142
# Dimension: Trail, Reference: 38_R_142
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/reference/142
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/correct_probe/142
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_1/141
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_2/145
#
#
# Key: Trail_39_G_134
# Dimension: Trail, Reference: 39_G_134
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/reference/134
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/correct_probe/134
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_1/334
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_2/434
#
#
# Key: Trail_40_G_256
# Dimension: Trail, Reference: 40_G_256
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/reference/256
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/correct_probe/256
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_1/456
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_2/356
#
#
# Key: Trail_41_G_251
# Dimension: Trail, Reference: 41_G_251
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/reference/251
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/correct_probe/251
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_1/451
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_2/151
#
#
# Key: Trail_42_G_113
# Dimension: Trail, Reference: 42_G_113
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/reference/113
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/correct_probe/113
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_1/213
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_2/413
#
#
# Key: Trail_43_G_236
# Dimension: Trail, Reference: 43_G_236
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/reference/236
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/correct_probe/236
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_1/436
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_2/336
#
#
# Key: Trail_44_R_426
# Dimension: Trail, Reference: 44_R_426
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/reference/426
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/correct_probe/426
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_1/423
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_2/421
#
#
# Key: Trail_45_T_255
# Dimension: Trail, Reference: 45_T_255
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/reference/255
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/correct_probe/255
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_1/245
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_2/235
#
#
# Key: Trail_46_R_125
# Dimension: Trail, Reference: 46_R_125
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/reference/125
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/correct_probe/125
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_1/124
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_2/126
#
#
# Key: Trail_47_G_354
# Dimension: Trail, Reference: 47_G_354
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/reference/354
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/correct_probe/354
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_1/254
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_2/454
#
#
# Key: Trail_48_R_235
# Dimension: Trail, Reference: 48_R_235
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/reference/235
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/correct_probe/235
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_1/236
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_2/232
#
#
# Key: Trail_49_T_344
# Dimension: Trail, Reference: 49_T_344
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/reference/344
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/correct_probe/344
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_1/324
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_2/314
#
#
# Key: Trail_50_R_431
# Dimension: Trail, Reference: 50_R_431
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/reference/431
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/correct_probe/431
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_1/435
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_2/434
#
#
# Key: Trail_51_G_344
# Dimension: Trail, Reference: 51_G_344
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/reference/344
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/correct_probe/344
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_1/144
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_2/444
#
#
# Key: Trail_52_T_112
# Dimension: Trail, Reference: 52_T_112
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/reference/112
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/correct_probe/112
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_1/122
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_2/152
#
#
# Key: Trail_53_G_152
# Dimension: Trail, Reference: 53_G_152
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/reference/152
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/correct_probe/152
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_1/252
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_2/452
#
#
# Key: Trail_54_R_336
# Dimension: Trail, Reference: 54_R_336
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/reference/336
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/correct_probe/336
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_1/332
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_2/333
#
#
# Key: Trail_55_T_136
# Dimension: Trail, Reference: 55_T_136
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/reference/136
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/correct_probe/136
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_1/126
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_2/116
#
#
# Key: Trail_56_G_144
# Dimension: Trail, Reference: 56_G_144
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/reference/144
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/correct_probe/144
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_1/444
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_2/244
#
#
# Key: Trail_57_R_323
# Dimension: Trail, Reference: 57_R_323
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/reference/323
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/correct_probe/323
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_1/321
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_2/322
#
#
# Key: Trail_58_R_315
# Dimension: Trail, Reference: 58_R_315
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/reference/315
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/correct_probe/315
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_1/314
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_2/311
#
#
# Key: Trail_59_G_353
# Dimension: Trail, Reference: 59_G_353
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/reference/353
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/correct_probe/353
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_1/453
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_2/253
#
#
# Key: Trail_60_G_451
# Dimension: Trail, Reference: 60_G_451
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/reference/451
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/correct_probe/451
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_1/351
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_2/251
#
#
# Key: Trail_61_T_312
# Dimension: Trail, Reference: 61_T_312
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/reference/312
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/correct_probe/312
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_1/322
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_2/342
#
#
# Key: Trail_62_R_226
# Dimension: Trail, Reference: 62_R_226
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/reference/226
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/correct_probe/226
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_1/224
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_2/221
#
#
# Key: Trail_63_G_252
# Dimension: Trail, Reference: 63_G_252
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/reference/252
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/correct_probe/252
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_1/452
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_2/352
#
#
# Key: Trail_64_R_343
# Dimension: Trail, Reference: 64_R_343
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/reference/343
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/correct_probe/343
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_1/345
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_2/342
#
#
# Key: Trail_65_G_141
# Dimension: Trail, Reference: 65_G_141
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/reference/141
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/correct_probe/141
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_1/341
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_2/241
#
#
# Key: Trail_66_R_223
# Dimension: Trail, Reference: 66_R_223
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/reference/223
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/correct_probe/223
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_1/226
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_2/225
#
#
# Key: Trail_67_T_335
# Dimension: Trail, Reference: 67_T_335
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/reference/335
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/correct_probe/335
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_1/345
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_2/325
#
#
# Key: Trail_68_G_322
# Dimension: Trail, Reference: 68_G_322
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/reference/322
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/correct_probe/322
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_1/422
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_2/222
#
#
# Key: Trail_69_T_146
# Dimension: Trail, Reference: 69_T_146
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/reference/146
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/correct_probe/146
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_1/126
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_2/136
#
#
# Key: Trail_70_G_253
# Dimension: Trail, Reference: 70_G_253
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/reference/253
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/correct_probe/253
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_1/453
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_2/153
#
#
# Key: Trail_71_G_131
# Dimension: Trail, Reference: 71_G_131
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/reference/131
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/correct_probe/131
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_1/331
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_2/231
#
#
# Key: Trail_72_G_414
# Dimension: Trail, Reference: 72_G_414
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/reference/414
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/correct_probe/414
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_1/314
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_2/114
#
#
# Key: Trail_73_R_452
# Dimension: Trail, Reference: 73_R_452
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/reference/452
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/correct_probe/452
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_1/453
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_2/455
#
#
# Key: Trail_74_R_416
# Dimension: Trail, Reference: 74_R_416
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/reference/416
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/correct_probe/416
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_1/414
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_2/415
#
#
# Key: Trail_75_G_115
# Dimension: Trail, Reference: 75_G_115
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/reference/115
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/correct_probe/115
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_1/415
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_2/215
#
#
# Key: Trail_76_G_314
# Dimension: Trail, Reference: 76_G_314
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/reference/314
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/correct_probe/314
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_1/414
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_2/214
#
#
# Key: Trail_77_R_145
# Dimension: Trail, Reference: 77_R_145
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/reference/145
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/correct_probe/145
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_1/144
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_2/146
#
#
# Key: Trail_78_T_142
# Dimension: Trail, Reference: 78_T_142
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/reference/142
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/correct_probe/142
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_1/112
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_2/132
#
#
# Key: Trail_79_G_411
# Dimension: Trail, Reference: 79_G_411
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/reference/411
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/correct_probe/411
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_1/111
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_2/311
#
#
# Key: Trail_80_R_311
# Dimension: Trail, Reference: 80_R_311
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/reference/311
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/correct_probe/311
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_1/315
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_2/314
#
#
# Key: Trail_81_T_155
# Dimension: Trail, Reference: 81_T_155
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/reference/155
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/correct_probe/155
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_1/135
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_2/115
#
#
# Key: Trail_82_T_423
# Dimension: Trail, Reference: 82_T_423
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/reference/423
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/correct_probe/423
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_1/433
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_2/453
#
#
# Key: Trail_83_T_223
# Dimension: Trail, Reference: 83_T_223
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/reference/223
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/correct_probe/223
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_1/233
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_2/253
#
#
# Key: Trail_84_R_243
# Dimension: Trail, Reference: 84_R_243
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/reference/243
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/correct_probe/243
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_1/245
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_2/244
#
#
# Key: Trail_85_T_321
# Dimension: Trail, Reference: 85_T_321
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/reference/321
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/correct_probe/321
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_1/341
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_2/331
#
#
# Key: Trail_86_T_441
# Dimension: Trail, Reference: 86_T_441
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/reference/441
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/correct_probe/441
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_1/451
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_2/421
#
#
# Key: Trail_87_T_243
# Dimension: Trail, Reference: 87_T_243
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/reference/243
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/correct_probe/243
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_1/233
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_2/213
#
#
# Key: Trail_88_T_342
# Dimension: Trail, Reference: 88_T_342
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/reference/342
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/correct_probe/342
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_1/312
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_2/322
#
#
# Key: Trail_89_T_325
# Dimension: Trail, Reference: 89_T_325
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/reference/325
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/correct_probe/325
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_1/315
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_2/335
#
#
# Key: Trail_90_T_433
# Dimension: Trail, Reference: 90_T_433
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/reference/433
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/correct_probe/433
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_1/443
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_2/453
#
#
# Key: Trail_91_T_353
# Dimension: Trail, Reference: 91_T_353
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/reference/353
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/correct_probe/353
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_1/333
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_2/323
#
#
# Key: Trail_92_T_132
# Dimension: Trail, Reference: 92_T_132
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/reference/132
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/correct_probe/132
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_1/112
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_2/142
#
#
# Key: Trail_93_G_325
# Dimension: Trail, Reference: 93_G_325
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/reference/325
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/correct_probe/325
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_1/425
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_2/225
#
#
# Key: Trail_94_G_231
# Dimension: Trail, Reference: 94_G_231
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/reference/231
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/correct_probe/231
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_1/431
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_2/331
#
#
# Key: Trail_95_R_222
# Dimension: Trail, Reference: 95_R_222
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/reference/222
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/correct_probe/222
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_1/225
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_2/224
#
#
# Key: Trail_96_T_345
# Dimension: Trail, Reference: 96_T_345
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/reference/345
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/correct_probe/345
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_1/355
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_2/325
#
#
# Key: Trail_97_R_134
# Dimension: Trail, Reference: 97_R_134
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/reference/134
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/correct_probe/134
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_1/131
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_2/135
#
#
# Key: Trail_98_R_211
# Dimension: Trail, Reference: 98_R_211
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/reference/211
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/correct_probe/211
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_1/214
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_2/213
#
#
# Key: Trail_99_G_142
# Dimension: Trail, Reference: 99_G_142
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/reference/142
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/correct_probe/142
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_1/442
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_2/342
#
#
# Key: Trail_100_R_334
# Dimension: Trail, Reference: 100_R_334
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/reference/334
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/correct_probe/334
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_1/333
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_2/332
#
#
# Key: Trail_101_T_324
# Dimension: Trail, Reference: 101_T_324
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/reference/324
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/correct_probe/324
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_1/334
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_2/344
#
#
# Key: Trail_102_R_153
# Dimension: Trail, Reference: 102_R_153
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/reference/153
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/correct_probe/153
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_1/152
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_2/154
#
#
# Key: Trail_103_G_334
# Dimension: Trail, Reference: 103_G_334
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/reference/334
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/correct_probe/334
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_1/234
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_2/134
#
#
# Key: Trail_104_R_225
# Dimension: Trail, Reference: 104_R_225
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/reference/225
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/correct_probe/225
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_1/222
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_2/224
#
#
# Key: Trail_105_T_233
# Dimension: Trail, Reference: 105_T_233
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/reference/233
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/correct_probe/233
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_1/213
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_2/253
#
#
# Key: Trail_106_R_141
# Dimension: Trail, Reference: 106_R_141
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/reference/141
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/correct_probe/141
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_1/142
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_2/143
#
#
# Key: Trail_107_T_421
# Dimension: Trail, Reference: 107_T_421
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/reference/421
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/correct_probe/421
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_1/441
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_2/431
#
#
# Key: Trail_108_T_331
# Dimension: Trail, Reference: 108_T_331
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/reference/331
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/correct_probe/331
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_1/321
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_2/311
#
#
# Key: Trail_109_G_215
# Dimension: Trail, Reference: 109_G_215
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/reference/215
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/correct_probe/215
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_1/115
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_2/315
#
#
# Key: Trail_110_T_322
# Dimension: Trail, Reference: 110_T_322
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/reference/322
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/correct_probe/322
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_1/312
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_2/332
#
#
# Key: Trail_111_G_425
# Dimension: Trail, Reference: 111_G_425
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/reference/425
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/correct_probe/425
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_1/125
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_2/325
#
#
# Key: Trail_112_R_313
# Dimension: Trail, Reference: 112_R_313
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/reference/313
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/correct_probe/313
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_1/314
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_2/315
#
#
# Key: Trail_113_G_246
# Dimension: Trail, Reference: 113_G_246
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/reference/246
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/correct_probe/246
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_1/146
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_2/446
#
#
# Key: Trail_114_G_442
# Dimension: Trail, Reference: 114_G_442
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/reference/442
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/correct_probe/442
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_1/342
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_2/142
#
#
# Key: Trail_115_R_152
# Dimension: Trail, Reference: 115_R_152
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/reference/152
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/correct_probe/152
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_1/155
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_2/154
#
#
# Key: Trail_116_R_444
# Dimension: Trail, Reference: 116_R_444
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/reference/444
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/correct_probe/444
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_1/446
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_2/442
#
#
# Key: Trail_117_G_216
# Dimension: Trail, Reference: 117_G_216
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/reference/216
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/correct_probe/216
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_1/316
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_2/416
#
#
# Key: Trail_118_G_123
# Dimension: Trail, Reference: 118_G_123
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/reference/123
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/correct_probe/123
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_1/223
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_2/423
#
#
# Key: Trail_119_T_444
# Dimension: Trail, Reference: 119_T_444
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/reference/444
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/correct_probe/444
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_1/424
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_2/414
#
#
# Key: Trail_120_G_136
# Dimension: Trail, Reference: 120_G_136
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/reference/136
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/correct_probe/136
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_1/436
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_2/236
#
#
# Key: Trail_121_T_451
# Dimension: Trail, Reference: 121_T_451
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/reference/451
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/correct_probe/451
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_1/421
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_2/431
#
#
# Key: Trail_122_G_416
# Dimension: Trail, Reference: 122_G_416
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/reference/416
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/correct_probe/416
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_1/316
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_2/116
#
#
# Key: Trail_123_G_316
# Dimension: Trail, Reference: 123_G_316
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/reference/316
# ...
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_1/221
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_2/321
#
#
# Key: Trail_326_G_245
# Dimension: Trail, Reference: 326_G_245
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/reference/245
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/correct_probe/245
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_1/145
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_2/445
#
#
# Key: Trail_327_R_126
# Dimension: Trail, Reference: 327_R_126
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/reference/126
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/correct_probe/126
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_1/125
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_2/122
#
#
# Key: Trail_328_R_353
# Dimension: Trail, Reference: 328_R_353
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/reference/353
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/correct_probe/353
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_1/354
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_2/351
#
#
# Key: Trail_329_R_415
# Dimension: Trail, Reference: 329_R_415
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/reference/415
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/correct_probe/415
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_1/416
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_2/414
#
#
# Key: Trail_330_T_156
# Dimension: Trail, Reference: 330_T_156
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/reference/156
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/correct_probe/156
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_1/136
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_2/126
#
#
# Key: Trail_331_R_232
# Dimension: Trail, Reference: 331_R_232
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/reference/232
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/correct_probe/232
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_1/235
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_2/231
#
#
# Key: Trail_332_G_154
# Dimension: Trail, Reference: 332_G_154
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/reference/154
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/correct_probe/154
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_1/354
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_2/454
#
#
# Key: Trail_333_G_146
# Dimension: Trail, Reference: 333_G_146
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/reference/146
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/correct_probe/146
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_1/246
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_2/446
#
#
# Key: Trail_334_T_143
# Dimension: Trail, Reference: 334_T_143
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/reference/143
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/correct_probe/143
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_1/113
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_2/133
#
#
# Key: Trail_335_G_315
# Dimension: Trail, Reference: 335_G_315
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/reference/315
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/correct_probe/315
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_1/115
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_2/215
#
#
# Key: Trail_336_R_214
# Dimension: Trail, Reference: 336_R_214
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/reference/214
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/correct_probe/214
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_1/212
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_2/216
#
#
# Key: Trail_337_G_122
# Dimension: Trail, Reference: 337_G_122
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/reference/122
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/correct_probe/122
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_1/422
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_2/322
#
#
# Key: Trail_338_T_215
# Dimension: Trail, Reference: 338_T_215
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/reference/215
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/correct_probe/215
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_1/225
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_2/255
#
#
# Key: Trail_339_G_412
# Dimension: Trail, Reference: 339_G_412
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/reference/412
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/correct_probe/412
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_1/212
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_2/112
#
#
# Key: Trail_340_T_315
# Dimension: Trail, Reference: 340_T_315
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/reference/315
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/correct_probe/315
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_1/335
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_2/355
#
#
# Key: Trail_341_G_453
# Dimension: Trail, Reference: 341_G_453
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/reference/453
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/correct_probe/453
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_1/153
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_2/253
#
#
# Key: Trail_342_T_212
# Dimension: Trail, Reference: 342_T_212
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/reference/212
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/correct_probe/212
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_1/242
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_2/232
#
#
# Key: Trail_343_G_424
# Dimension: Trail, Reference: 343_G_424
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/reference/424
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/correct_probe/424
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_1/224
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_2/324
#
#
# Key: Trail_344_G_244
# Dimension: Trail, Reference: 344_G_244
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/reference/244
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/correct_probe/244
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_1/144
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_2/344
#
#
# Key: Trail_345_T_151
# Dimension: Trail, Reference: 345_T_151
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/reference/151
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/correct_probe/151
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_1/111
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_2/131
#
#
# Key: Trail_346_R_316
# Dimension: Trail, Reference: 346_R_316
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/reference/316
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/correct_probe/316
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_1/315
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_2/311
#
#
# Key: Trail_347_R_155
# Dimension: Trail, Reference: 347_R_155
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/reference/155
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/correct_probe/155
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_1/152
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_2/153
#
#
# Key: Trail_348_R_312
# Dimension: Trail, Reference: 348_R_312
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/reference/312
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/correct_probe/312
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_1/314
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_2/315
#
#
# Key: Trail_349_T_144
# Dimension: Trail, Reference: 349_T_144
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/reference/144
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/correct_probe/144
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_1/124
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_2/154
#
#
# Key: Trail_350_R_122
# Dimension: Trail, Reference: 350_R_122
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/reference/122
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/correct_probe/122
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_1/121
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_2/126
#
#
# Key: Trail_351_G_443
# Dimension: Trail, Reference: 351_G_443
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/reference/443
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/correct_probe/443
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_1/143
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_2/243
#
#
# Key: Trail_352_R_453
# Dimension: Trail, Reference: 352_R_453
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/reference/453
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/correct_probe/453
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_1/452
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_2/454
#
#
# Key: Trail_353_G_415
# Dimension: Trail, Reference: 353_G_415
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/reference/415
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/correct_probe/415
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_1/115
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_2/315
#
#
# Key: Trail_354_R_215
# Dimension: Trail, Reference: 354_R_215
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/reference/215
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/correct_probe/215
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_1/212
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_2/214
#
#
# Key: Trail_355_R_454
# Dimension: Trail, Reference: 355_R_454
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/reference/454
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/correct_probe/454
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_1/456
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_2/453
#
#
# Key: Trail_356_T_226
# Dimension: Trail, Reference: 356_T_226
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/reference/226
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/correct_probe/226
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_1/246
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_2/256
#
#
# Key: Trail_357_G_423
# Dimension: Trail, Reference: 357_G_423
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/reference/423
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/correct_probe/423
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_1/123
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_2/323
#
#
# Key: Trail_358_G_312
# Dimension: Trail, Reference: 358_G_312
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/reference/312
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/correct_probe/312
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_1/412
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_2/112
#
#
# Key: Trail_359_G_455
# Dimension: Trail, Reference: 359_G_455
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/reference/455
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/correct_probe/455
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_1/155
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/G/variant_probe_2/255
#
#
# Key: Trail_360_T_123
# Dimension: Trail, Reference: 360_T_123
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/reference/123
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/correct_probe/123
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_1/143
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_2/133
#
#
# Key: Trail_361_T_221
# Dimension: Trail, Reference: 361_T_221
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/reference/221
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/correct_probe/221
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_1/241
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_2/211
#
#
# Key: Trail_362_T_141
# Dimension: Trail, Reference: 362_T_141
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/reference/141
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/correct_probe/141
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_1/111
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_2/151
#
#
# Key: Trail_363_T_445
# Dimension: Trail, Reference: 363_T_445
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/reference/445
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/correct_probe/445
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_1/455
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_2/435
#
#
# Key: Trail_364_R_456
# Dimension: Trail, Reference: 364_R_456
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/reference/456
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/correct_probe/456
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_1/454
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/R/variant_probe_2/453
#
#
# Key: Trail_365_T_311
# Dimension: Trail, Reference: 365_T_311
# Reference Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/reference/311
# Correct Probe Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/correct_probe/311
# Variant Probe 1 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_1/321
# Variant Probe 2 Path: /storageNVME/kcriss/gtr_dataset_evaluation/T/variant_probe_2/351

# %%
# save trials_mapping to a list
trials_mapping_list = []
for reference, info in trials_mapping.items():
    trials_mapping_list.append({
        'reference': reference,
        'dimension': info['dimension'],
        'reference_path': info['reference_path'],
        'correct_probe_path': info['correct_probe_path'],
        'variant_probe_paths': info['variant_probe_paths']
    })

# %%
import os
import shutil


# 源目录路径，其中存放了.wav音频文件
source_dir = '/storageNVME/kcriss/gtr_dataset_sliced_FREEZE/gtr_125'

# 遍历trials_mapping_list中的每个条目
for trial in trials_mapping_list:
    # 处理correct_probe
    correct_probe_gtr_combination = trial['reference_path'].split('/')[-1]
    correct_probe_source_dir = os.path.join(source_dir, correct_probe_gtr_combination)
    if os.path.exists(correct_probe_source_dir):
        for i in range(1, 21):  
            src_file = os.path.join(correct_probe_source_dir, f'{i:02}.wav')
            if os.path.exists(src_file):
                shutil.copy(src_file, trial['reference_path'])
    else:
        print(f"Source directory does not exist: {correct_probe_source_dir}")


    # for variant_path in trial['variant_probe_paths']:
    #     variant_gtr_combination = variant_path.split('/')[-1]
    #     variant_source_dir = os.path.join(source_dir, variant_gtr_combination)
    #     if os.path.exists(variant_source_dir):
    #         for i in range(1, 21): 
    #             src_file = os.path.join(variant_source_dir, f'{i:02}.wav')
    #             if os.path.exists(src_file):
    #                 shutil.copy(src_file, variant_path)
    #     else:
    #         print(f"Source directory does not exist: {variant_source_dir}")

# %%
# save list to a json file
import json
with open('trials_mapping.json', 'w') as f:
    json.dump(trials_mapping_list, f, indent=4)

# %%
html_fixed_head_content = '''
<!DOCTYPE html>
<html lang="en">
<head>
<style>
  table audio {
          width: 100%;
          max-width: 300px; 
  }
  table {
          width: 100%;
          border-collapse: collapse;
      }

      table, th, td {
          border: 1px solid black;
      }

      th, td {
          padding: 10px;
          text-align: left;
      }
</style>

<body>

<!-- Global site tag (gtag.js) - Google Analytics -->
<script async src=""></script>
<script>
  window.dataLayer = window.dataLayer || [];

  function gtag() {
    dataLayer.push(arguments);
  }

  gtag('js', new Date());

  gtag('config', '');
</script>

<section>
  <div>

    
    <div>
      <div>
        <h1>Subjective Evaluation (主观评估)</h1>
        <p>Thank you for participating in the subjective evaluation. (感谢您参与本主观评估测试。)</p>
          <p><strong>Instructions (测试说明)</strong>: </p>
            <p>1. You will hear 18~19 groups of voices, each group contains a reference voice and three test voices. (你将听到18~19组语音，每组语音包含一个参考语音和三个测试语音。)</p>
            <p>2. The text content of the reference voice is different from the text content of the test voice. (参考语音的文本内容与测试语音的文本内容不同。)</p>
            <p>3. Click the triangle button on the left side of the audio block with the mouse to play the audio. (用鼠标点击音频块左侧的三角形按钮播放音频。)</p>
            <p>4. You need to choose one of the three test voices that is most similar to the reference voice, and click the corresponding round single selection button with the mouse. (你需要在三个测试语音中选择一个与参考最相似的语音，并用鼠标点击相应的圆形单选按钮。)</p>
          <p><strong>Most similar might mean (最相似可能意味着):</strong> </p>
          <ul>
            <li><strong>The pitch/timbre of the voice is similar (语音的音高/音色相似)</strong></li>
            <li><strong>The style/speed/rhythm of the pronunciation of the voice is similar (语音的吐字或发声方式以及风格相似)</strong></li>
          </ul>
          <br>
    '''

# %%
html_fixed_tail_content = '''


    <br><br>

        <!-- Submit button -->
            <div style="text-align: center;">
                <input type="submit" value="Complete" style="width: 150px; height: 50px;">
            </div>
            </form>

            <div id="resultText" style="text-align: center; display: none;">
                <p>Please copy the following text and paste it into Google Forms(请复制以下文本并粘贴到Google Forms中):</p>
                <textarea id="resultOutput"></textarea>
            </div>
            <div style="display: flex; justify-content: center; margin-top: 20px;"> <!-- 开始一个新的 div 用于 iframe -->
                <iframe src="https://docs.google.com/forms/d/e/1FAIpQLSdJdZbJIQPeFQHEHIbMKYjmjL0gGPGhx08AY8G-hoFcD3QeSA/viewform?embedded=true" width="640" height="451" frameborder="0" marginheight="0" marginwidth="0">Loading…</iframe>
            </div>
            </section>
        </div>
  <script>
  document.getElementById('evaluationForm').onsubmit = function(event) {
      event.preventDefault(); // 阻止表单默认提交行为

      var resultArray = [];
      var currentTime = new Date().toISOString();
      var evaluationIdx = document.getElementById('evaluationIdx').value; // 从隐藏的输入获取evaluation_idx
      var evaluationNumber = "evaluation_" + evaluationIdx; // 使用evaluation_idx构建评估编号

      resultArray.push(evaluationNumber);

      // 获取每个group的用户选择
      var choices = [];
      for (var i = 1; i <= 18; i++) {
          var groupName = "group_" + i;
          var selectedValue = document.querySelector('input[name="' + groupName + '"]:checked')?.value;
          choices.push(selectedValue || "N/A");
      }

      resultArray.push(choices.join(","));

      // 显示结果文本并填充到textarea中
      var resultText = resultArray.join(",");
      document.getElementById('resultOutput').textContent = resultText;
      document.getElementById('resultText').style.display = 'block';
  };
  </script>
          var resultText = resultArray.join(",");
          var resultOutput = document.getElementById('resultOutput');
          resultOutput.textContent = resultText;
          resultOutput.style.height = 'auto';
          resultOutput.style.height = (resultOutput.scrollHeight) + 'px';
          document.getElementById('resultText').style.display = 'block';
</body>
</html>
'''

# %%
# generate html  
import random

def generate_groups_html(trials_mapping_list, start_index, end_index, evaluation_idx=1):
    html_output = ""
    
    form_html_start = '<form id="evaluationForm">'
    hidden_input_for_evaluation_idx = f'<input type="hidden" id="evaluationIdx" value="{evaluation_idx}">'
    form_html = form_html_start + hidden_input_for_evaluation_idx

    server_root_prefix = "/storageNVME/kcriss/gtr_dataset_evaluation/"

    for i in range(start_index, end_index):
        trial = trials_mapping_list[i]
        # 将绝对路径转换为相对于服务器根目录的相对路径
        reference_audio_rel_path = trial['reference_path'].replace(server_root_prefix, "")
        correct_probe_audio_rel_path = trial['correct_probe_path'].replace(server_root_prefix, "")
        variant_probe_audios_rel_paths = [vp.replace(server_root_prefix, "") for vp in trial['variant_probe_paths']]

        # 随机选择一个.wav文件编号
        selected_file_number = f"{random.randint(1, 20):02}.wav"

        # 生成音频标签，引用随机选择的相同编号的.wav文件
        reference_tag = f'<td style="text-align: center"><audio src="{reference_audio_rel_path}/{selected_file_number}" style="max-width: 300px;" type="audio/wav" controls controlsList="nodownload noplaybackrate"></audio></td>'
        correct_probe_tag = f'<td style="text-align: center"><audio src="{correct_probe_audio_rel_path}/{selected_file_number}" style="max-width: 300px;" type="audio/wav" controls controlsList="nodownload noplaybackrate"></audio></td>'
        variant_probe_tags = ''.join([f'<td style="text-align: center"><audio src="{vp_rel_path}/{selected_file_number}" style="max-width: 300px;" type="audio/wav" controls controlsList="nodownload noplaybackrate"></audio></td>' for vp_rel_path in variant_probe_audios_rel_paths])  
        
        # 生成单选按钮
        radio_buttons = ''.join([
                f'<td style="text-align: center;"><input type="radio" id="group_{i+1}_choice_{j+1}" name="group_{i+1}" value="{j+1}" required><label for="group_{i+1}_choice_{j+1}">This one is most similar to reference</label></td>'
                for j in range(3)
        ])

        # 拼接完整的HTML代码
        group_html = f'''

        <!-- Group {i+1-start_index} -->
        <h3>Group {i+1-start_index}</h3>
        <div>
        </div>
        <div><table style="table-layout:fixed;">
            <col span="1" style="width: 25%;">
            <col span="1" style="width: 25%;">
            <col span="1" style="width: 25%;">
            <col span="1" style="width: 25%;">
            <thead>
                <tr>
                    <th style="text-align: center">Reference</th>
                    <th style="text-align: center">Test Sample 1</th>
                    <th style="text-align: center">Test Sample 2</th>
                    <th style="text-align: center">Test Sample 3</th>
                </tr>
            </thead>
            <tbody>
                <tr>{reference_tag}{correct_probe_tag}{variant_probe_tags}</tr>
                <tr>
                <td>&#128204; Which speech sample(Sample 1, Sample 2, Sample 3) sounds most similar to the reference?</td>
                {radio_buttons}
                </tr>
            </tbody>
        </table></div>
        <!-- End of Group {i+1-start_index}. -->
        
        '''
        
  
        html_output += group_html + "\n\n"

    html_output = html_fixed_head_content + form_html + html_output + html_fixed_tail_content

    return html_output

# %%
# 生成第一个HTML文档的代码，包含第1到第18组
html_content_1 = generate_groups_html(trials_mapping_list, 0, 18, 1)
# save to file
with open('evaluation_1.html', 'w') as f:
    f.write(html_content_1)

# # 生成第二个HTML文档的代码，包含第19到第37组
# html_content_2 = generate_groups_html(trials_mapping_list, 18, 37)
# # save to file
# with open('evaluation_2.html', 'w') as f:
#     f.write(html_content_2)

# %%
# show root working directory
# !pwd
# Out:
# /storageNVME/kcriss/gtr_dataset_evaluation
